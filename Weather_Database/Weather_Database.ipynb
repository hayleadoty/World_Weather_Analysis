# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
import requests
from config import weather_api_key
from datetime import datetime

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        for d in city_weather["weather"]:
            city_description = d["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lensk
# Processing Record 2 of Set 1 | mar del plata
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | kokoda
# Processing Record 5 of Set 1 | hasaki
# Processing Record 6 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 7 of Set 1 | castro
# Processing Record 8 of Set 1 | miguel hidalgo
# Processing Record 9 of Set 1 | volsk
# Processing Record 10 of Set 1 | soyo
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | jacareacanga
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | thompson
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | omboue
# Processing Record 17 of Set 1 | bajo baudo
# City not found. Skipping...
# Processing Record 18 of Set 1 | goderich
# Processing Record 19 of Set 1 | mehamn
# Processing Record 20 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 1 | mitu
# Processing Record 22 of Set 1 | barrow
# Processing Record 23 of Set 1 | pandan
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | jieshi
# Processing Record 28 of Set 1 | isla mujeres
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | bintulu
# Processing Record 31 of Set 1 | khatanga
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | boda
# Processing Record 34 of Set 1 | georgetown
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | srednekolymsk
# Processing Record 38 of Set 1 | gorontalo
# Processing Record 39 of Set 1 | bambous virieux
# Processing Record 40 of Set 1 | college
# Processing Record 41 of Set 1 | rosario do sul
# Processing Record 42 of Set 1 | iquique
# Processing Record 43 of Set 1 | jiaxing
# Processing Record 44 of Set 1 | havoysund
# Processing Record 45 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 1 | leningradskiy
# Processing Record 47 of Set 1 | lompoc
# Processing Record 48 of Set 1 | vostok
# Processing Record 49 of Set 1 | yahotyn
# Processing Record 50 of Set 1 | nikolskoye
# Processing Record 1 of Set 2 | victoria
# Processing Record 2 of Set 2 | tasiilaq
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | cukai
# Processing Record 5 of Set 2 | beira
# Processing Record 6 of Set 2 | albany
# Processing Record 7 of Set 2 | sao felix do xingu
# Processing Record 8 of Set 2 | bafra
# Processing Record 9 of Set 2 | nouakchott
# Processing Record 10 of Set 2 | killybegs
# Processing Record 11 of Set 2 | huarmey
# Processing Record 12 of Set 2 | port elizabeth
# Processing Record 13 of Set 2 | iskateley
# Processing Record 14 of Set 2 | dubuque
# Processing Record 15 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 2 | ilulissat
# Processing Record 17 of Set 2 | guerrero negro
# Processing Record 18 of Set 2 | klaksvik
# Processing Record 19 of Set 2 | iqaluit
# Processing Record 20 of Set 2 | balykshi
# Processing Record 21 of Set 2 | kaitangata
# Processing Record 22 of Set 2 | ixtapa
# Processing Record 23 of Set 2 | hobart
# Processing Record 24 of Set 2 | hermanus
# Processing Record 25 of Set 2 | qaanaaq
# Processing Record 26 of Set 2 | hithadhoo
# Processing Record 27 of Set 2 | chokurdakh
# Processing Record 28 of Set 2 | honiara
# Processing Record 29 of Set 2 | cidreira
# Processing Record 30 of Set 2 | caronport
# Processing Record 31 of Set 2 | tenenkou
# Processing Record 32 of Set 2 | chihuahua
# Processing Record 33 of Set 2 | torbay
# Processing Record 34 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 2 | chimore
# Processing Record 37 of Set 2 | sitka
# Processing Record 38 of Set 2 | asau
# Processing Record 39 of Set 2 | itarema
# Processing Record 40 of Set 2 | penzance
# Processing Record 41 of Set 2 | vaini
# Processing Record 42 of Set 2 | carnarvon
# Processing Record 43 of Set 2 | butaritari
# Processing Record 44 of Set 2 | galesong
# Processing Record 45 of Set 2 | mvomero
# Processing Record 46 of Set 2 | san felipe
# Processing Record 47 of Set 2 | sabang
# Processing Record 48 of Set 2 | hilo
# Processing Record 49 of Set 2 | broken hill
# Processing Record 50 of Set 2 | ponta delgada
# Processing Record 1 of Set 3 | muros
# Processing Record 2 of Set 3 | khormuj
# City not found. Skipping...
# Processing Record 3 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 4 of Set 3 | binga
# Processing Record 5 of Set 3 | ambilobe
# Processing Record 6 of Set 3 | esperance
# Processing Record 7 of Set 3 | myitkyina
# Processing Record 8 of Set 3 | luderitz
# Processing Record 9 of Set 3 | sao joao da barra
# Processing Record 10 of Set 3 | souillac
# Processing Record 11 of Set 3 | sur
# Processing Record 12 of Set 3 | mahibadhoo
# Processing Record 13 of Set 3 | nanortalik
# Processing Record 14 of Set 3 | goure
# Processing Record 15 of Set 3 | saint-philippe
# Processing Record 16 of Set 3 | ambanja
# Processing Record 17 of Set 3 | geresk
# City not found. Skipping...
# Processing Record 18 of Set 3 | bontang
# Processing Record 19 of Set 3 | nathdwara
# Processing Record 20 of Set 3 | ishigaki
# Processing Record 21 of Set 3 | sembe
# Processing Record 22 of Set 3 | puerto ayora
# Processing Record 23 of Set 3 | the valley
# Processing Record 24 of Set 3 | westport
# Processing Record 25 of Set 3 | severnoye
# Processing Record 26 of Set 3 | mayor pablo lagerenza
# Processing Record 27 of Set 3 | mersing
# Processing Record 28 of Set 3 | darnah
# Processing Record 29 of Set 3 | rypin
# Processing Record 30 of Set 3 | poum
# Processing Record 31 of Set 3 | roslavl
# Processing Record 32 of Set 3 | port lincoln
# Processing Record 33 of Set 3 | airai
# Processing Record 34 of Set 3 | san cristobal
# Processing Record 35 of Set 3 | lebu
# Processing Record 36 of Set 3 | atuona
# Processing Record 37 of Set 3 | tuktoyaktuk
# Processing Record 38 of Set 3 | padang
# Processing Record 39 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 3 | anadyr
# Processing Record 41 of Set 3 | belaya gora
# Processing Record 42 of Set 3 | bristol
# Processing Record 43 of Set 3 | bull savanna
# Processing Record 44 of Set 3 | tezu
# Processing Record 45 of Set 3 | bathsheba
# Processing Record 46 of Set 3 | kodiak
# Processing Record 47 of Set 3 | richards bay
# Processing Record 48 of Set 3 | scarborough
# Processing Record 49 of Set 3 | lavrentiya
# Processing Record 50 of Set 3 | thaton
# Processing Record 1 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 4 | taoudenni
# Processing Record 3 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 4 | tarakan
# Processing Record 5 of Set 4 | houma
# Processing Record 6 of Set 4 | san quintin
# Processing Record 7 of Set 4 | provideniya
# Processing Record 8 of Set 4 | grindavik
# Processing Record 9 of Set 4 | praia
# Processing Record 10 of Set 4 | kavaratti
# Processing Record 11 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 4 | aksarka
# Processing Record 13 of Set 4 | sambava
# Processing Record 14 of Set 4 | tilichiki
# Processing Record 15 of Set 4 | isangel
# Processing Record 16 of Set 4 | sindor
# Processing Record 17 of Set 4 | tiksi
# Processing Record 18 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 4 | narsaq
# Processing Record 20 of Set 4 | orangevale
# Processing Record 21 of Set 4 | roma
# Processing Record 22 of Set 4 | prince rupert
# Processing Record 23 of Set 4 | ambatondrazaka
# Processing Record 24 of Set 4 | tomatlan
# Processing Record 25 of Set 4 | kavieng
# Processing Record 26 of Set 4 | east london
# Processing Record 27 of Set 4 | sarangani
# Processing Record 28 of Set 4 | saldanha
# Processing Record 29 of Set 4 | ginda
# Processing Record 30 of Set 4 | wanning
# Processing Record 31 of Set 4 | pisco
# Processing Record 32 of Set 4 | yellowknife
# Processing Record 33 of Set 4 | tashigang
# Processing Record 34 of Set 4 | urbana
# Processing Record 35 of Set 4 | puerto escondido
# Processing Record 36 of Set 4 | omsukchan
# Processing Record 37 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 4 | fez
# Processing Record 39 of Set 4 | micheweni
# Processing Record 40 of Set 4 | lagoa
# Processing Record 41 of Set 4 | katsuura
# Processing Record 42 of Set 4 | los llanos de aridane
# Processing Record 43 of Set 4 | kushiro
# Processing Record 44 of Set 4 | caravelas
# Processing Record 45 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 4 | rocha
# Processing Record 47 of Set 4 | conceicao do araguaia
# Processing Record 48 of Set 4 | anage
# Processing Record 49 of Set 4 | ayia galini
# Processing Record 50 of Set 4 | igrim
# Processing Record 1 of Set 5 | aswan
# Processing Record 2 of Set 5 | talnakh
# Processing Record 3 of Set 5 | breves
# Processing Record 4 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 5 | erdenet
# Processing Record 6 of Set 5 | vagur
# Processing Record 7 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 5 | vila velha
# Processing Record 9 of Set 5 | ribeira grande
# Processing Record 10 of Set 5 | faanui
# Processing Record 11 of Set 5 | angouleme
# Processing Record 12 of Set 5 | ponta do sol
# Processing Record 13 of Set 5 | soure
# Processing Record 14 of Set 5 | caninde
# Processing Record 15 of Set 5 | yulara
# Processing Record 16 of Set 5 | jingdezhen
# Processing Record 17 of Set 5 | fairbanks
# Processing Record 18 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 19 of Set 5 | dikson
# Processing Record 20 of Set 5 | kruisfontein
# Processing Record 21 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 5 | saskylakh
# Processing Record 23 of Set 5 | vermillion
# Processing Record 24 of Set 5 | jalingo
# Processing Record 25 of Set 5 | khani
# Processing Record 26 of Set 5 | ruwi
# Processing Record 27 of Set 5 | santa cruz
# Processing Record 28 of Set 5 | upernavik
# Processing Record 29 of Set 5 | bardiyah
# Processing Record 30 of Set 5 | galle
# Processing Record 31 of Set 5 | mount gambier
# Processing Record 32 of Set 5 | sao jose da coroa grande
# Processing Record 33 of Set 5 | andenes
# Processing Record 34 of Set 5 | new norfolk
# Processing Record 35 of Set 5 | erzin
# Processing Record 36 of Set 5 | khandbari
# Processing Record 37 of Set 5 | khilok
# Processing Record 38 of Set 5 | fortuna
# Processing Record 39 of Set 5 | salalah
# Processing Record 40 of Set 5 | berlevag
# Processing Record 41 of Set 5 | bijapur
# Processing Record 42 of Set 5 | quanzhou
# Processing Record 43 of Set 5 | taltal
# Processing Record 44 of Set 5 | egvekinot
# Processing Record 45 of Set 5 | grand gaube
# Processing Record 46 of Set 5 | codrington
# Processing Record 47 of Set 5 | verkhnevilyuysk
# Processing Record 48 of Set 5 | karamea
# City not found. Skipping...
# Processing Record 49 of Set 5 | constitucion
# Processing Record 50 of Set 5 | tashtagol
# Processing Record 1 of Set 6 | talaya
# Processing Record 2 of Set 6 | planadas
# Processing Record 3 of Set 6 | ruteng
# Processing Record 4 of Set 6 | dingle
# Processing Record 5 of Set 6 | taperoa
# Processing Record 6 of Set 6 | pocone
# Processing Record 7 of Set 6 | ranibennur
# Processing Record 8 of Set 6 | severo-kurilsk
# Processing Record 9 of Set 6 | margate
# Processing Record 10 of Set 6 | sao domingos
# Processing Record 11 of Set 6 | port victoria
# Processing Record 12 of Set 6 | beringovskiy
# Processing Record 13 of Set 6 | boende
# Processing Record 14 of Set 6 | fuyu
# Processing Record 15 of Set 6 | laramie
# Processing Record 16 of Set 6 | neyshabur
# Processing Record 17 of Set 6 | anloga
# Processing Record 18 of Set 6 | sabha
# Processing Record 19 of Set 6 | salinas
# Processing Record 20 of Set 6 | dutlwe
# Processing Record 21 of Set 6 | eufaula
# Processing Record 22 of Set 6 | chapais
# Processing Record 23 of Set 6 | brahmapuri
# City not found. Skipping...
# Processing Record 24 of Set 6 | ilam
# Processing Record 25 of Set 6 | phuthaditjhaba
# Processing Record 26 of Set 6 | santa maria
# Processing Record 27 of Set 6 | muyezerskiy
# Processing Record 28 of Set 6 | misratah
# Processing Record 29 of Set 6 | half moon bay
# Processing Record 30 of Set 6 | xining
# Processing Record 31 of Set 6 | salisbury
# Processing Record 32 of Set 6 | birao
# Processing Record 33 of Set 6 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 34 of Set 6 | gao
# Processing Record 35 of Set 6 | meulaboh
# Processing Record 36 of Set 6 | dunedin
# Processing Record 37 of Set 6 | clyde river
# Processing Record 38 of Set 6 | kitgum
# Processing Record 39 of Set 6 | wajid
# Processing Record 40 of Set 6 | booue
# Processing Record 41 of Set 6 | samarai
# Processing Record 42 of Set 6 | longyearbyen
# Processing Record 43 of Set 6 | mulchen
# Processing Record 44 of Set 6 | kalemie
# Processing Record 45 of Set 6 | naron
# Processing Record 46 of Set 6 | kloulklubed
# Processing Record 47 of Set 6 | cabuyaro
# Processing Record 48 of Set 6 | ochakiv
# Processing Record 49 of Set 6 | aban
# Processing Record 50 of Set 6 | carballo
# Processing Record 1 of Set 7 | namibe
# Processing Record 2 of Set 7 | jamestown
# Processing Record 3 of Set 7 | ancud
# Processing Record 4 of Set 7 | sinnamary
# Processing Record 5 of Set 7 | tamiahua
# Processing Record 6 of Set 7 | etchoropo
# Processing Record 7 of Set 7 | ossora
# Processing Record 8 of Set 7 | the pas
# Processing Record 9 of Set 7 | alice springs
# Processing Record 10 of Set 7 | geraldton
# Processing Record 11 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 7 | tarko-sale
# Processing Record 13 of Set 7 | bengkulu
# Processing Record 14 of Set 7 | sao lourenco do sul
# Processing Record 15 of Set 7 | broome
# Processing Record 16 of Set 7 | waddan
# Processing Record 17 of Set 7 | ahipara
# Processing Record 18 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 7 | arraial do cabo
# Processing Record 20 of Set 7 | luganville
# Processing Record 21 of Set 7 | lotoshino
# Processing Record 22 of Set 7 | constantine
# Processing Record 23 of Set 7 | shiyan
# Processing Record 24 of Set 7 | nouadhibou
# Processing Record 25 of Set 7 | tabuk
# Processing Record 26 of Set 7 | tornio
# Processing Record 27 of Set 7 | maputo
# Processing Record 28 of Set 7 | gerash
# Processing Record 29 of Set 7 | tirau
# Processing Record 30 of Set 7 | arman
# Processing Record 31 of Set 7 | hohoe
# Processing Record 32 of Set 7 | slave lake
# Processing Record 33 of Set 7 | lekoni
# Processing Record 34 of Set 7 | altamira
# Processing Record 35 of Set 7 | waingapu
# Processing Record 36 of Set 7 | cherskiy
# Processing Record 37 of Set 7 | chuy
# Processing Record 38 of Set 7 | poland
# Processing Record 39 of Set 7 | mahenge
# Processing Record 40 of Set 7 | faaborg
# Processing Record 41 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 7 | shizunai
# Processing Record 43 of Set 7 | marsh harbour
# Processing Record 44 of Set 7 | bani
# Processing Record 45 of Set 7 | mahebourg
# Processing Record 46 of Set 7 | morondava
# Processing Record 47 of Set 7 | plettenberg bay
# Processing Record 48 of Set 7 | solec kujawski
# Processing Record 49 of Set 7 | faya
# Processing Record 50 of Set 7 | silver city
# Processing Record 1 of Set 8 | hongjiang
# Processing Record 2 of Set 8 | senador jose porfirio
# Processing Record 3 of Set 8 | urumqi
# Processing Record 4 of Set 8 | kosonsoy
# Processing Record 5 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 8 | snezhnogorsk
# Processing Record 7 of Set 8 | avera
# Processing Record 8 of Set 8 | kasempa
# Processing Record 9 of Set 8 | chon daen
# Processing Record 10 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 11 of Set 8 | biak
# Processing Record 12 of Set 8 | tinskoy
# Processing Record 13 of Set 8 | tucumcari
# Processing Record 14 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 8 | saint george
# Processing Record 16 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 8 | sibsagar
# Processing Record 18 of Set 8 | tunduru
# City not found. Skipping...
# Processing Record 19 of Set 8 | portales
# Processing Record 20 of Set 8 | davila
# Processing Record 21 of Set 8 | kungurtug
# Processing Record 22 of Set 8 | rundu
# Processing Record 23 of Set 8 | kuala terengganu
# Processing Record 24 of Set 8 | makat
# Processing Record 25 of Set 8 | wajir
# Processing Record 26 of Set 8 | cabedelo
# Processing Record 27 of Set 8 | sistranda
# Processing Record 28 of Set 8 | bonavista
# Processing Record 29 of Set 8 | kawana waters
# City not found. Skipping...
# Processing Record 30 of Set 8 | abha
# Processing Record 31 of Set 8 | sorong
# Processing Record 32 of Set 8 | siyabuswa
# Processing Record 33 of Set 8 | siaya
# Processing Record 34 of Set 8 | grootfontein
# Processing Record 35 of Set 8 | amparafaravola
# Processing Record 36 of Set 8 | aldan
# Processing Record 37 of Set 8 | kokopo
# Processing Record 38 of Set 8 | kahului
# Processing Record 39 of Set 8 | morgan city
# Processing Record 40 of Set 8 | natal
# Processing Record 41 of Set 8 | pangnirtung
# Processing Record 42 of Set 8 | inuvik
# Processing Record 43 of Set 8 | vao
# Processing Record 44 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 45 of Set 8 | coahuayana
# Processing Record 46 of Set 8 | kenai
# Processing Record 47 of Set 8 | high level
# Processing Record 48 of Set 8 | sardulgarh
# Processing Record 49 of Set 8 | okhotsk
# Processing Record 50 of Set 8 | nishihara
# Processing Record 1 of Set 9 | villa bruzual
# Processing Record 2 of Set 9 | ust-tsilma
# Processing Record 3 of Set 9 | bakaly
# Processing Record 4 of Set 9 | san patricio
# Processing Record 5 of Set 9 | ankazoabo
# Processing Record 6 of Set 9 | almaznyy
# Processing Record 7 of Set 9 | antalaha
# Processing Record 8 of Set 9 | gamba
# Processing Record 9 of Set 9 | terrace bay
# Processing Record 10 of Set 9 | saint-joseph
# Processing Record 11 of Set 9 | chimoio
# Processing Record 12 of Set 9 | betera
# Processing Record 13 of Set 9 | leninskiy
# Processing Record 14 of Set 9 | cabesti
# Processing Record 15 of Set 9 | port blair
# Processing Record 16 of Set 9 | ust-maya
# Processing Record 17 of Set 9 | curuca
# Processing Record 18 of Set 9 | catamarca
# Processing Record 19 of Set 9 | kalmunai
# Processing Record 20 of Set 9 | lincoln
# Processing Record 21 of Set 9 | abu samrah
# Processing Record 22 of Set 9 | bolshaya irba
# City not found. Skipping...
# Processing Record 23 of Set 9 | ferkessedougou
# Processing Record 24 of Set 9 | vetapalem
# Processing Record 25 of Set 9 | vardo
# Processing Record 26 of Set 9 | paamiut
# Processing Record 27 of Set 9 | bethel
# Processing Record 28 of Set 9 | krabi
# Processing Record 29 of Set 9 | moron
# Processing Record 30 of Set 9 | springdale
# Processing Record 31 of Set 9 | perelyub
# Processing Record 32 of Set 9 | hendijan
# City not found. Skipping...
# Processing Record 33 of Set 9 | armidale
# Processing Record 34 of Set 9 | teguldet
# Processing Record 35 of Set 9 | tessalit
# Processing Record 36 of Set 9 | black river
# Processing Record 37 of Set 9 | komsomolskiy
# Processing Record 38 of Set 9 | tonantins
# Processing Record 39 of Set 9 | san rafael
# Processing Record 40 of Set 9 | anar darreh
# City not found. Skipping...
# Processing Record 41 of Set 9 | sydney mines
# Processing Record 42 of Set 9 | saint-pierre
# Processing Record 43 of Set 9 | quatre cocos
# Processing Record 44 of Set 9 | shingu
# Processing Record 45 of Set 9 | aripuana
# Processing Record 46 of Set 9 | ulaanbaatar
# Processing Record 47 of Set 9 | nelson bay
# Processing Record 48 of Set 9 | luanda
# Processing Record 49 of Set 9 | horasan
# Processing Record 50 of Set 9 | kajaani
# Processing Record 1 of Set 10 | dryden
# Processing Record 2 of Set 10 | lloydminster
# Processing Record 3 of Set 10 | kieta
# Processing Record 4 of Set 10 | saint-augustin
# Processing Record 5 of Set 10 | mae chan
# Processing Record 6 of Set 10 | surman
# Processing Record 7 of Set 10 | havre-saint-pierre
# Processing Record 8 of Set 10 | trincomalee
# Processing Record 9 of Set 10 | saint-georges
# Processing Record 10 of Set 10 | puerto ayacucho
# Processing Record 11 of Set 10 | bilma
# Processing Record 12 of Set 10 | huruta
# Processing Record 13 of Set 10 | nemuro
# Processing Record 14 of Set 10 | saint-francois
# Processing Record 15 of Set 10 | riyadh
# Processing Record 16 of Set 10 | cordoba
# Processing Record 17 of Set 10 | deer lake
# Processing Record 18 of Set 10 | inirida
# Processing Record 19 of Set 10 | alyangula
# Processing Record 20 of Set 10 | aklavik
# Processing Record 21 of Set 10 | roald
# Processing Record 22 of Set 10 | gat
# Processing Record 23 of Set 10 | tokur
# Processing Record 24 of Set 10 | teguise
# Processing Record 25 of Set 10 | poykovskiy
# Processing Record 26 of Set 10 | tecoanapa
# Processing Record 27 of Set 10 | shache
# Processing Record 28 of Set 10 | taitung
# Processing Record 29 of Set 10 | mount isa
# Processing Record 30 of Set 10 | amancio
# City not found. Skipping...
# Processing Record 31 of Set 10 | fuling
# Processing Record 32 of Set 10 | katherine
# Processing Record 33 of Set 10 | novorudnyy
# Processing Record 34 of Set 10 | potam
# Processing Record 35 of Set 10 | verkhniy landekh
# Processing Record 36 of Set 10 | tiruchchendur
# Processing Record 37 of Set 10 | mahanje
# Processing Record 38 of Set 10 | beaverlodge
# Processing Record 39 of Set 10 | saint leonard
# Processing Record 40 of Set 10 | flinders
# Processing Record 41 of Set 10 | adrar
# Processing Record 42 of Set 10 | doka
# Processing Record 43 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 44 of Set 10 | verkhnyaya inta
# Processing Record 45 of Set 10 | sotara
# City not found. Skipping...
# Processing Record 46 of Set 10 | norman wells
# Processing Record 47 of Set 10 | fare
# Processing Record 48 of Set 10 | wa
# City not found. Skipping...
# Processing Record 49 of Set 10 | whitehorse
# Processing Record 50 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 1 of Set 11 | cabo san lucas
# Processing Record 2 of Set 11 | nizhniy kuranakh
# Processing Record 3 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 4 of Set 11 | tuatapere
# Processing Record 5 of Set 11 | severo-yeniseyskiy
# Processing Record 6 of Set 11 | pedernales
# Processing Record 7 of Set 11 | kolda
# Processing Record 8 of Set 11 | redmond
# Processing Record 9 of Set 11 | tongren
# Processing Record 10 of Set 11 | puerto del rosario
# Processing Record 11 of Set 11 | nome
# Processing Record 12 of Set 11 | harper
# Processing Record 13 of Set 11 | valentin gomez farias
# Processing Record 14 of Set 11 | coquimbo
# Processing Record 15 of Set 11 | mitsamiouli
# Processing Record 16 of Set 11 | bolobo
# Processing Record 17 of Set 11 | aksarayskiy
# Processing Record 18 of Set 11 | spornoye
# Processing Record 19 of Set 11 | tabou
# Processing Record 20 of Set 11 | songjianghe
# Processing Record 21 of Set 11 | laguna
# Processing Record 22 of Set 11 | atambua
# Processing Record 23 of Set 11 | pevek
# Processing Record 24 of Set 11 | along
# Processing Record 25 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 26 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 27 of Set 11 | tacarigua
# Processing Record 28 of Set 11 | mattru
# Processing Record 29 of Set 11 | nanyang
# Processing Record 30 of Set 11 | umm kaddadah
# Processing Record 31 of Set 11 | hami
# Processing Record 32 of Set 11 | villa carlos paz
# Processing Record 33 of Set 11 | najran
# Processing Record 34 of Set 11 | vestmannaeyjar
# Processing Record 35 of Set 11 | verkh-neyvinskiy
# Processing Record 36 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 37 of Set 11 | alofi
# Processing Record 38 of Set 11 | surakarta
# Processing Record 39 of Set 11 | gizo
# Processing Record 40 of Set 11 | menomonie
# Processing Record 41 of Set 11 | aguimes
# Processing Record 42 of Set 11 | maulvi bazar
# City not found. Skipping...
# Processing Record 43 of Set 11 | khandyga
# Processing Record 44 of Set 11 | kipini
# Processing Record 45 of Set 11 | amapa
# Processing Record 46 of Set 11 | banda aceh
# Processing Record 47 of Set 11 | tawnat
# City not found. Skipping...
# Processing Record 48 of Set 11 | popova
# Processing Record 49 of Set 11 | chernenko
# Processing Record 50 of Set 11 | marawi
# Processing Record 1 of Set 12 | yinchuan
# Processing Record 2 of Set 12 | tevaitoa
# Processing Record 3 of Set 12 | barra do garcas
# Processing Record 4 of Set 12 | alushta
# Processing Record 5 of Set 12 | sahuaripa
# Processing Record 6 of Set 12 | nichinan
# Processing Record 7 of Set 12 | tura
# Processing Record 8 of Set 12 | narasannapeta
# Processing Record 9 of Set 12 | jumla
# Processing Record 10 of Set 12 | tutoia
# Processing Record 11 of Set 12 | umri
# Processing Record 12 of Set 12 | talara
# Processing Record 13 of Set 12 | porto santo
# Processing Record 14 of Set 12 | sierre
# Processing Record 15 of Set 12 | vershino-shakhtaminskiy
# Processing Record 16 of Set 12 | kidal
# Processing Record 17 of Set 12 | trelew
# Processing Record 18 of Set 12 | norfolk
# Processing Record 19 of Set 12 | benjamin constant
# Processing Record 20 of Set 12 | rostaq
# City not found. Skipping...
# Processing Record 21 of Set 12 | abu dhabi
# Processing Record 22 of Set 12 | kisangani
# Processing Record 23 of Set 12 | katha
# City not found. Skipping...
# Processing Record 24 of Set 12 | hobyo
# Processing Record 25 of Set 12 | obo
# Processing Record 26 of Set 12 | chernyshkovskiy
# Processing Record 27 of Set 12 | requena
# Processing Record 28 of Set 12 | bartica
# Processing Record 29 of Set 12 | plouzane
# Processing Record 30 of Set 12 | santa isabel
# Processing Record 31 of Set 12 | cacu
# Processing Record 32 of Set 12 | ukiah
# Processing Record 33 of Set 12 | soderhamn
# Processing Record 34 of Set 12 | te anau
# Processing Record 35 of Set 12 | takestan
# Processing Record 36 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 37 of Set 12 | ambovombe
# Processing Record 38 of Set 12 | celestun
# Processing Record 39 of Set 12 | maceio
# Processing Record 40 of Set 12 | matipo
# Processing Record 41 of Set 12 | kosh-agach
# Processing Record 42 of Set 12 | nur
# Processing Record 43 of Set 12 | yeppoon
# Processing Record 44 of Set 12 | puerto leguizamo
# Processing Record 45 of Set 12 | sao filipe
# Processing Record 46 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 47 of Set 12 | shinpokh
# Processing Record 48 of Set 12 | buqayq
# City not found. Skipping...
# Processing Record 49 of Set 12 | nelidovo
# Processing Record 50 of Set 12 | highview
# Processing Record 1 of Set 13 | yerakarou
# City not found. Skipping...
# Processing Record 2 of Set 13 | nesbyen
# Processing Record 3 of Set 13 | linfen
# Processing Record 4 of Set 13 | kulu
# Processing Record 5 of Set 13 | rawson
# Processing Record 6 of Set 13 | pumiao
# Processing Record 7 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 8 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 13 | povenets
# Processing Record 10 of Set 13 | yaan
# Processing Record 11 of Set 13 | islamkot
# Processing Record 12 of Set 13 | port-gentil
# Processing Record 13 of Set 13 | tahta
# Processing Record 14 of Set 13 | mengcheng
# Processing Record 15 of Set 13 | heishan
# Processing Record 16 of Set 13 | anshun
# Processing Record 17 of Set 13 | mbandaka
# Processing Record 18 of Set 13 | marfino
# Processing Record 19 of Set 13 | mandalgovi
# Processing Record 20 of Set 13 | podgorica
# Processing Record 21 of Set 13 | lubango
# Processing Record 22 of Set 13 | skibbereen
# Processing Record 23 of Set 13 | vila franca do campo
# Processing Record 24 of Set 13 | opuwo
# Processing Record 25 of Set 13 | galdar
# Processing Record 26 of Set 13 | bullhead city
# Processing Record 27 of Set 13 | monrovia
# Processing Record 28 of Set 13 | boyolangu
# Processing Record 29 of Set 13 | maarianhamina
# Processing Record 30 of Set 13 | price
# Processing Record 31 of Set 13 | einsiedeln
# Processing Record 32 of Set 13 | san luis
# Processing Record 33 of Set 13 | mbulu
# Processing Record 34 of Set 13 | nagorsk
# Processing Record 35 of Set 13 | manzil jamil
# City not found. Skipping...
# Processing Record 36 of Set 13 | kedungwuni
# Processing Record 37 of Set 13 | zhuhai
# Processing Record 38 of Set 13 | xilokastron
# City not found. Skipping...
# Processing Record 39 of Set 13 | comodoro rivadavia
# Processing Record 40 of Set 13 | deputatskiy
# Processing Record 41 of Set 13 | omagh
# Processing Record 42 of Set 13 | illapel
# Processing Record 43 of Set 13 | puertollano
# Processing Record 44 of Set 13 | santa cruz de la palma
# Processing Record 45 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 13 | rock sound
# Processing Record 47 of Set 13 | papetoai
# Processing Record 48 of Set 13 | beyla
# Processing Record 49 of Set 13 | tual
# Processing Record 50 of Set 13 | anicuns
# Processing Record 1 of Set 14 | fengzhen
# Processing Record 2 of Set 14 | changli
# Processing Record 3 of Set 14 | virginia beach
# Processing Record 4 of Set 14 | shimoda
# Processing Record 5 of Set 14 | maseru
# Processing Record 6 of Set 14 | tiznit
# Processing Record 7 of Set 14 | novouzensk
# Processing Record 8 of Set 14 | lephepe
# City not found. Skipping...
# Processing Record 9 of Set 14 | yar-sale
# Processing Record 10 of Set 14 | kokubu
# Processing Record 11 of Set 14 | borlange
# City not found. Skipping...
# Processing Record 12 of Set 14 | touros
# Processing Record 13 of Set 14 | tigil
# Processing Record 14 of Set 14 | bowen
# Processing Record 15 of Set 14 | guerrero
# Processing Record 16 of Set 14 | makakilo city
# Processing Record 17 of Set 14 | bongandanga
# Processing Record 18 of Set 14 | yakima
# Processing Record 19 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 20 of Set 14 | ambon
# Processing Record 21 of Set 14 | taga dzong
# City not found. Skipping...
# Processing Record 22 of Set 14 | takoradi
# Processing Record 23 of Set 14 | pahrump
# Processing Record 24 of Set 14 | congonhas
# Processing Record 25 of Set 14 | batemans bay
# Processing Record 26 of Set 14 | mana
# Processing Record 27 of Set 14 | cascais
# Processing Record 28 of Set 14 | surt
# Processing Record 29 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 30 of Set 14 | atouguia da baleia
# Processing Record 31 of Set 14 | cayenne
# Processing Record 32 of Set 14 | auki
# Processing Record 33 of Set 14 | ust-kuyga
# Processing Record 34 of Set 14 | calama
# Processing Record 35 of Set 14 | yakshur-bodya
# City not found. Skipping...
# Processing Record 36 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 37 of Set 14 | sharjah
# Processing Record 38 of Set 14 | valdivia
# Processing Record 39 of Set 14 | ewa beach
# Processing Record 40 of Set 14 | trapani
# Processing Record 41 of Set 14 | matara
# Processing Record 42 of Set 14 | haizhou
# Processing Record 43 of Set 14 | waipawa
# Processing Record 44 of Set 14 | ayan
# Processing Record 45 of Set 14 | oum hadjer
# Processing Record 46 of Set 14 | oakley
# Processing Record 47 of Set 14 | samoded
# Processing Record 48 of Set 14 | quilmana
# Processing Record 49 of Set 14 | batagay-alyta
# Processing Record 50 of Set 14 | neiafu
# Processing Record 1 of Set 15 | gawler
# Processing Record 2 of Set 15 | cravo norte
# Processing Record 3 of Set 15 | ostrovskoye
# Processing Record 4 of Set 15 | changping
# Processing Record 5 of Set 15 | jamsa
# Processing Record 6 of Set 15 | colorines
# Processing Record 7 of Set 15 | ugoofaaru
# Processing Record 8 of Set 15 | quelimane
# Processing Record 9 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 10 of Set 15 | ushtobe
# Processing Record 11 of Set 15 | suez
# Processing Record 12 of Set 15 | yate
# Processing Record 13 of Set 15 | ostersund
# Processing Record 14 of Set 15 | leh
# Processing Record 15 of Set 15 | panama city
# Processing Record 16 of Set 15 | bahadurganj
# Processing Record 17 of Set 15 | lanigan
# Processing Record 18 of Set 15 | vila
# Processing Record 19 of Set 15 | palembang
# Processing Record 20 of Set 15 | colonia leopoldina
# Processing Record 21 of Set 15 | bon accord
# Processing Record 22 of Set 15 | inongo
# Processing Record 23 of Set 15 | kargasok
# Processing Record 24 of Set 15 | dujuma
# City not found. Skipping...
# Processing Record 25 of Set 15 | parry sound
# Processing Record 26 of Set 15 | liverpool
# Processing Record 27 of Set 15 | alihe
# Processing Record 28 of Set 15 | balabac
# Processing Record 29 of Set 15 | maragogi
# Processing Record 30 of Set 15 | kysyl-syr
# Processing Record 31 of Set 15 | maniitsoq
# Processing Record 32 of Set 15 | okato
# Processing Record 33 of Set 15 | manadhoo
# Processing Record 34 of Set 15 | sakakah
# Processing Record 35 of Set 15 | toyooka
# Processing Record 36 of Set 15 | mbala
# Processing Record 37 of Set 15 | savonlinna
# Processing Record 38 of Set 15 | den chai
# Processing Record 39 of Set 15 | kirriemuir
# Processing Record 40 of Set 15 | jalu
# Processing Record 41 of Set 15 | kantemirovka
# Processing Record 42 of Set 15 | kaifeng
# Processing Record 43 of Set 15 | kutum
# Processing Record 44 of Set 15 | labuhan
# Processing Record 45 of Set 15 | umm jarr
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 676

# %%
# Convert the array of dictionaries into a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Lensk  60.7253  114.9278    -35.10        80         100
# 1   Mar Del Plata -38.0023  -57.5575     64.40        55          90
# 2          Avarua -21.2078 -159.7750     75.20        94          98
# 3          Kokoda  -8.8785  147.7407     77.05        65         100
# 4          Hasaki  35.7333  140.8333     26.60        80          20
# 5          Castro -24.7911  -50.0119     72.63        86          90
# 6  Miguel Hidalgo  19.4225  -99.2028     66.20        39          40
# 7           Volsk  52.0333   47.3833     33.69        96         100
# 8            Soyo  -6.1349   12.3689     81.50        80          98
# 9         Rikitea -23.1203 -134.9692     79.07        74          74
#
#    Wind Speed Country Current Description
# 0        2.68      RU     overcast clouds
# 1       23.02      AR     overcast clouds
# 2        1.14      CK     overcast clouds
# 3        6.44      PG       moderate rain
# 4       14.41      JP          few clouds
# 5        5.97      BR     overcast clouds
# 6        3.44      MX    scattered clouds
# 7       10.13      RU     overcast clouds
# 8        9.73      AO     overcast clouds
# 9       10.80      PF          light rain

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Lensk      RU  60.7253  114.9278    -35.10        80         100
# 1   Mar Del Plata      AR -38.0023  -57.5575     64.40        55          90
# 2          Avarua      CK -21.2078 -159.7750     75.20        94          98
# 3          Kokoda      PG  -8.8785  147.7407     77.05        65         100
# 4          Hasaki      JP  35.7333  140.8333     26.60        80          20
# 5          Castro      BR -24.7911  -50.0119     72.63        86          90
# 6  Miguel Hidalgo      MX  19.4225  -99.2028     66.20        39          40
# 7           Volsk      RU  52.0333   47.3833     33.69        96         100
# 8            Soyo      AO  -6.1349   12.3689     81.50        80          98
# 9         Rikitea      PF -23.1203 -134.9692     79.07        74          74
#
#    Wind Speed Current Description
# 0        2.68     overcast clouds
# 1       23.02     overcast clouds
# 2        1.14     overcast clouds
# 3        6.44       moderate rain
# 4       14.41          few clouds
# 5        5.97     overcast clouds
# 6        3.44    scattered clouds
# 7       10.13     overcast clouds
# 8        9.73     overcast clouds
# 9       10.80          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
